# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedhavalli-Sarkunnan/ToDoList/blob/main/notebooks/text_fake_news_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p src/text results/text notebooks

# %%
# !ls
# Out:
# notebooks  results  src
